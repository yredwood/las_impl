# %%
# %matplotlib inline

import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns


uniform_data = np.load('temp.npy')
#uniform_data = np.random.rand(10,12)
# figure = plt.figure(figsize=(20))
ax = sns.heatmap(np.log(uniform_data[0]))
plt.show()

# %%
print (np.log(uniform_data[0]))
# Out:
# [[-5.618197  -5.628     -5.627915  ... -5.579884  -5.5399737 -5.506196 ]
#  [-3.721004  -4.3056407 -4.702177  ... -5.034989  -4.8325295 -4.542131 ]
#  [-3.9228277 -4.4400897 -4.774946  ... -5.115533  -4.8498993 -4.511716 ]
#  ...
#  [-3.287121  -4.092813  -4.4859834 ... -4.40684   -3.8898644 -3.4385016]
#  [-4.2036095 -4.5600147 -4.8280854 ... -4.699914  -4.305421  -3.9339547]
#  [-3.5907042 -4.2290773 -4.5866027 ... -4.525528  -3.999396  -3.5109355]]
