# %%
# %matplotlib inline

import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns


uniform_data = np.load('models/att_bs128.hdim128.cdim640.convn6.lr0.1.tfp0.0.npy')
print (uniform_data.shape)
#uniform_data = np.random.rand(10,12)
figure = plt.figure(figsize=(20,20))
ax = sns.heatmap((uniform_data[3]))
plt.show()
# Out:
# (128, 318, 25)

# %%
print ((uniform_data[0]).shape)
print ((uniform_data[0]).argmax(1))
# Out:
# (334, 107)
# [23 23 23 61 23 59 61 23 23 59 61 23 23 23 23 23 23 23 23 23 23 23 23 23
#  23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23
#  23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23
#  23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23
#  23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23
#  23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23
#  23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23
#  23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23
#  23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23
#  23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23
#  23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23
#  23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23
#  23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23 23
# ...

# %%
fname = '652-130726-0028.npy'
data_root = 'data/libri_fbank80_char30/dev-clean'
import os
data = np.load(os.path.join(data_root, fname))

print (data.shape)
plt.figure(figsize=(20,20))
plt.imshow(data.transpose())

plt.show()
# Out:
# (303, 80)
